# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/Users/admin/Desktop/df_train.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
# 3           3  2015-01-01 12:00:00           1.000000           level_8
# 4           4  2015-01-01 15:00:00           1.000000           level_7
# 5           5  2015-01-01 18:00:00           1.000000           level_7
# 6           6  2015-01-01 21:00:00           1.000000           level_8
# 7           7  2015-01-02 00:00:00           1.000000           level_9
# 8           8  2015-01-02 03:00:00           1.000000           level_9
# 9           9  2015-01-02 06:00:00           1.000000           level_9
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# ...

# %%
#change wind degree and pressure to categorical data 
#convert madrid-rain_1h to madrid_3h
#Convert bilbao_rain_1h to Bilbao_3h

# %%
df.isnull().sum()
#check for null values
# Out:
# Unnamed: 0                 0
# time                       0
# Madrid_wind_speed          0
# Valencia_wind_deg          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# Madrid_humidity            0
# Bilbao_clouds_all          0
# Bilbao_wind_speed          0
# Seville_clouds_all         0
# Bilbao_wind_deg            0
# Barcelona_wind_speed       0
# Barcelona_wind_deg         0
# Madrid_clouds_all          0
# Seville_wind_speed         0
# Barcelona_rain_1h          0
# Seville_pressure           0
# Seville_rain_1h            0
# Bilbao_snow_3h             0
# Barcelona_pressure         0
# Seville_rain_3h            0
# Madrid_rain_1h             0
# Barcelona_rain_3h          0
# Valencia_snow_3h           0
# Madrid_weather_id          0
# Barcelona_weather_id       0
# Bilbao_pressure            0
# Seville_weather_id         0
# Valencia_pressure       2068
# Seville_temp_max           0
# Madrid_pressure            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8763 non-null   int64
#  1   time                  8763 non-null   object
#  2   Madrid_wind_speed     8763 non-null   float64
#  3   Valencia_wind_deg     8763 non-null   object
#  4   Bilbao_rain_1h        8763 non-null   float64
#  5   Valencia_wind_speed   8763 non-null   float64
#  6   Seville_humidity      8763 non-null   float64
#  7   Madrid_humidity       8763 non-null   float64
#  8   Bilbao_clouds_all     8763 non-null   float64
#  9   Bilbao_wind_speed     8763 non-null   float64
#  10  Seville_clouds_all    8763 non-null   float64
#  11  Bilbao_wind_deg       8763 non-null   float64
#  12  Barcelona_wind_speed  8763 non-null   float64
#  13  Barcelona_wind_deg    8763 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# count  8763.000000        8763.000000     8763.000000          8763.000000
# mean   4381.000000           2.425729        0.135753             2.586272
# std    2529.804538           1.850371        0.374901             2.411190
# min       0.000000           0.000000        0.000000             0.000000
# 25%    2190.500000           1.000000        0.000000             1.000000
# 50%    4381.000000           2.000000        0.000000             1.666667
# 75%    6571.500000           3.333333        0.100000             3.666667
# max    8762.000000          13.000000        3.000000            52.000000
#
#        Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# count       8763.000000      8763.000000        8763.000000
# mean          62.658793        57.414717          43.469132
# std           22.621226        24.335396          32.551044
# ...

# %%
df.kurtosis()
# Out:
# Unnamed: 0                -1.200000
# Madrid_wind_speed          2.036462
# Bilbao_rain_1h            32.904656
# Valencia_wind_speed       35.645426
# Seville_humidity          -1.017983
# Madrid_humidity           -1.167537
# Bilbao_clouds_all         -1.533417
# Bilbao_wind_speed          3.631565
# Seville_clouds_all         2.155921
# Bilbao_wind_deg           -1.083530
# Barcelona_wind_speed       1.493635
# Barcelona_wind_deg        -0.959160
# Madrid_clouds_all          0.142079
# Seville_wind_speed         1.398580
# Barcelona_rain_1h        101.578931
# Seville_rain_1h           93.840746
# Bilbao_snow_3h           806.128471
# Barcelona_pressure      3687.564230
# Seville_rain_3h          413.136592
# Madrid_rain_1h            76.584491
# Barcelona_rain_3h        187.800460
# Valencia_snow_3h        4089.323165
# Madrid_weather_id          9.259047
# Barcelona_weather_id       5.701882
# Bilbao_pressure            1.825323
# Seville_weather_id        10.710308
# ...

# %%
#majority of the factors contains less outliers in the data 
#kurtosis is <3

# %%
df[features].plot(kind='density', subplots=True, layout=(5, 5), sharex=False, figsize=(20, 20));

# %%
#Temperature plots. show that the temperature in Spain cities is generally centered around the range of 260-310 degree
#Whereas humidity is centered around 0-100 across all cities with a humidity measure
#Clouds_all all also show different/varying measures across all cities 
#wind degree also shows to be in the range 0-400 
#atmospheric pressure also show different/varying measures across all cities 
#whereas wind speed shows to have a varying range across cities in spain
#Rain acrros the cities in spain is centered around 0, which leads to the conclusion that it barely ever rains in spain across all the cities
#Spain cities generally do not snow , the density plots are centered around 0 for snow_3hrs
#We can conclude that the sources of renewable resources will most likely be affected by temperature, wind_deg,pressure, wind_speed ,humidity and clouds all

# %%
df.corr()
# Out:
#                       Unnamed: 0  Madrid_wind_speed  Bilbao_rain_1h  \
# Unnamed: 0              1.000000          -0.109288       -0.249633
# Madrid_wind_speed      -0.109288           1.000000        0.259719
# Bilbao_rain_1h         -0.249633           0.259719        1.000000
# Valencia_wind_speed    -0.090161           0.513092        0.265864
# Seville_humidity       -0.079025          -0.117892        0.069878
# Madrid_humidity        -0.103359          -0.137092        0.106765
# Bilbao_clouds_all      -0.068123           0.244001        0.370733
# Bilbao_wind_speed       0.049197           0.377854        0.085398
# Seville_clouds_all     -0.140583           0.191251        0.081131
# Bilbao_wind_deg        -0.155738           0.270950        0.279350
# Barcelona_wind_speed   -0.218781           0.294640        0.069997
# Barcelona_wind_deg     -0.140449          -0.095380       -0.030723
# Madrid_clouds_all      -0.116928           0.230126        0.135524
# ...

# %%
#Bilbao_wind_deg -0.120800
#Madride_wind_speed -0.150981 
#Valencia_wind_speed -0.142791
#Seville_humidity -0.167290
#Madrid_humidity -0.150536
#Bilbao_clouds_all -0.127293
#Bilbao_wind_speed -0.081602
#Seville_clouds_all -0.091804
#Barcelona_temp 0.182673
#Bilbao_temp 0.176411
#Madrid_temp 0.186036
#The temperature varaible has a weak positive correlation to the load shortfall, if temperature increases we have a higher load_shortfall value although the relationship is not strong
#This leads to the conclusion that renewable energy (solar energy specifically) has a strong dependency on temperature 
#wind degree, wind speed , clouds_all and humidity all have a negative correlation in relation to load_shortfall_3h , which means these factors are inversely proportional to load_shortfall and impact it negatively.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Madrid_temp",
                y="load_shortfall_3h",
                size="Madrid_clouds_all",
                sizes=(40,200),
                alpha=0.8,
                hue="Madrid_pressure",
                data=df);
#plotting correlations between all factors that will have an impact on loadshortfall#madrid clouds , pressure

# %%
#higher temperatures are seen at (5-7.5 km/hr wind speed), higher temperatures correspond to a medium wind_speed for madrid wind and madrid temperature.
#bigger. or higher clouds coeffecients correlate to a low temoerature and higher pressures
#Madrid has high atmospheric pressure regardless of the temperature and cloud sizes

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Madrid_temp",
                y="load_shortfall_3h",
                size="Madrid_wind_speed",
                sizes=(60,300),
                alpha=0.8,
                hue="Madrid_humidity",
                data=df);
#plotting correlations between all factors that will have an impact on loadshortfall#Madrid windspeed, humidity

# %%
#high wind speeds tend to be centered around a temperature of 280-290
#low humidity correlates to higher temperature, which we can conclude that humidity has a negative correlation to load shortfall
#

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Seville_temp",
                y="load_shortfall_3h",
                size="Seville_clouds_all",
                sizes=(40,200),
                alpha=0.8,
                hue="Seville_humidity",
                data=df);
#plotting correlations between all factors that will have an impact on loadshortfall#seville clouds, humidity and temp

# %%
#lower temperatures correlate to a higher humidity and higher clouds
#Therefore clouds and humidity can be concluded to have a negative correlation with loadshortfall_3h since temperature is positively correlated to loash_shortfall_3h

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Valencia_temp",
                y="load_shortfall_3h",
                size="Valencia_pressure",
                sizes=(60,300),
                alpha=0.8,
                hue="Valencia_wind_speed",
                data=df);
#plotting correlations between all factors that will have an impact on loadshortfall#valencia windspeed , pressure

# %%
#nothing much interesting with regards to colour and size distribution 
#wind speed and pressure fairly distributed across the temperature range in valencia

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Bilbao_temp",
                y="load_shortfall_3h",
                size="Bilbao_clouds_all",
                sizes=(60,300),
                alpha=0.8,
                hue="Bilbao_wind_speed",
                data=df);
#plotting correlations between all factors that will have an impact on loadshortfall#Bilbao clouds , windspeed

# %%
#higher clouds directly correlated to the lower side of temperatre across the range of temperature in bilbao

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Bilbao_temp",
                y="load_shortfall_3h",
                size="Bilbao_pressure",
                sizes=(60,300),
                alpha=0.8,
                hue="Bilbao_clouds_all",
                data=df);
#plotting correlations between all factors that will have an impact on loadshortfall#Bilbao clouds , pressure

# %%
#high clouds concentrated around 280-290 temperature 
#Pressure evenly distributed across the temperatre range 270-310

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Barcelona_temp",
                y="load_shortfall_3h",
                size="Barcelona_pressure",
                sizes=(100,300),
                alpha=0.8,
                hue="Barcelona_wind_speed",
                data=df);
#plotting correlations between all factors that will have an impact on loadshortfall#Bilbao windspeed , pressure

# %%
#nothing much interesting with regards to colour and size distribution 
#wind speed and pressure fairly distributed across the temperature range in Barelona

# %%
#from all the analysis across all the cities we can conclude that temperature is the leading factor to renewable energy and  loadshortfall, factors such as clouds and humidity are negatively correlated to tempperature and loadh_shortfall.

# %%
#for data engineering remove all other factors that. werent used in the bubble plots

# %%
ax = sns.violinplot(x="day", y="total_bill", hue="sex", data=tips)
ax.set_title('Distribution of total bill amount per day', fontsize=16);
